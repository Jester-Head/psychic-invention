# %%
import time

import pandas as pd
# import seaborn as sns
import selenium
# import webdriver_manager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.firefox.options import Options
import undetected_chromedriver.v2 as uc

# %%
# pip install undetected-chromedriver

# %%
# service = Service('C:\chromedriver_win32\chromedriver')
# driver = webdriver.Chrome('C:\chromedriver_win32\chromedriver')
# driver.quit()

options = uc.ChromeOptions()

# setting profile
options.user_data_dir = "c:\\temp\\profile"

# another way to set profile is the below (which takes precedence if both variants are used
options.add_argument('--user-data-dir=c:\\temp\\profile2')

#Change Browser Options
options.add_argument('proxy-server=106.122.8.54:3128')
options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.5249 Safari/537.36")
options.add_argument('--disable-blink-features=AutomationControlled')
options.add_argument('--start-maximized')


# just some options passing in to skip annoying popups
options.add_argument('--no-first-run --no-service-autorun --password-store=basic')
driver = uc.Chrome(options=options)
driver.quit()

# %%
url = 'https://us.forums.blizzard.com/en/wow/t/please-fix-momentum-before-launch-day/1381495'

# %%
with driver:
        driver.get(url)
        # comments = driver.find_elements(By.CSS_SELECTOR,'div.topic-body')
        # comments = WebDriverWait(driver, 10).until(EC.visibility_of_all_elements_located((By.CSS_SELECTOR,'class.post[itemprop="articleBody"]')))
        comments = driver.find_elements(By.XPATH,'//*[contains(concat( " ", @class, " " ), concat( " ", "cooked", " " ))]')
        # comments = driver.find_elements(By.XPATH,'.//*[@id="post_1"]/div/div[2]/div[2]/div[1]')
        comments = [com.text for com in comments]
        # comments = comments[3:]
        # time.sleep(randint(1,5))
        # author = driver.find_elements(By.XPATH,'.//*[contains(concat( " ", @class, " " ), concat( " ", "character-name", " " ))]')
        # author = [a.text for a in author]
        
        # df = pd.DataFrame(list(zip(comments,author)),columns=['comments','author'])
        df = pd.DataFrame(comments,columns=['comments'])

# %%
df

# %%
time.sleep(10)
driver.get('https://us.forums.blizzard.com/en/wow/c/classes/death-knight/175')
# driver.implicitly_wait(30)

dk = driver.find_elements(By.CSS_SELECTOR,'#ember66')
time.sleep(5)
creator = driver.find_elements(By.CSS_SELECTOR,'td.creator')
creator = [c.text for c in creator]
time.sleep(5)
topic = driver.find_elements(By.CSS_SELECTOR,'td.main-link.clearfix')
topic = [t.text for t in topic]
time.sleep(5)
replies = driver.find_elements(By.CSS_SELECTOR,'td.num.posts-map.posts.topic-list-data > button > span')
replies = [r.text for r in replies]
time.sleep(5)
views = driver.find_elements(By.CSS_SELECTOR,'td.num.views > span')
views = [v.text for v in views]
time.sleep(5)
link = driver.find_elements(By.CSS_SELECTOR,'td.main-link.clearfix > span > a')
link = [l.get_attribute('href') for l in link]

driver.quit()

# %%
dk = pd.DataFrame(list(zip(topic,creator,replies,views,link)),columns=['topic','author','replies','views','link'])
dk

# %%
driver.get('https://us.forums.blizzard.com/en/wow/c/classes/demon-hunter/176')
# driver.implicitly_wait(10)



creator = driver.find_elements(By.CSS_SELECTOR,'td.creator')
creator = [c.text for c in creator]

topic = driver.find_elements(By.CSS_SELECTOR,'td.main-link.clearfix')
topic = [t.text for t in topic]

replies = driver.find_elements(By.CSS_SELECTOR,'td.num.posts-map.posts.topic-list-data > button > span')
replies = [r.text for r in replies]

views = driver.find_elements(By.CSS_SELECTOR,'td.num.views > span')
views = [v.text for v in views]

link = driver.find_elements(By.CSS_SELECTOR,'td.main-link.clearfix > span > a')
link = [l.get_attribute('href') for l in link]

driver.quit()

# %%
dh = pd.DataFrame(list(zip(topic,creator,replies,views,link)),columns=['topic','author','replies','views','link'])
dh

# %%
driver.get('https://us.forums.blizzard.com/en/wow/t/nerf-soulrend-immediately/1390113')
# driver.implicitly_wait(30)
time.sleep(5)
# comments = driver.find_elements(By.CSS_SELECTOR,'div > div.topic-body.clearfix > div.regular.contents > div')
comments = driver.find_elements(By.XPATH,'//*[contains(concat( " ", @class, " " ), concat( " ", "cooked", " " ))]')

# %%
driver.quit()

# %%
comments = [com.text for com in comments]

# %%
comments

# %%
author = driver.find_elements(By.CLASS_NAME,'character-name')
author = [a.text for a in author]
author
# author = driver.find_elements(By.CLASS_NAME,'#post_1 > div > div.topic-body.clearfix > div.topic-meta-data > div.names.trigger-user-card > div > div > div.primary-details > a')

# %%
df = pd.read_csv('C:\\Users\\sarah\\OneDrive\Documents\\GitHub\\psychic-invention\\output')

# %%
# conda install Jinja2

# %%
pd.set_option('display.max_colwidth', None)
left_aligned_df = df.style.set_properties(**{'text-align': 'left'})

# %%
left_aligned_df

# %%
dfc = pd.read_csv(r'C:\Users\sarah\OneDrive\Documents\GitHub\psychic-invention\class_page')

# %%
dfc
# Out:
#                                                                           topic  \
# 0                             Still waiting on that Frostmourne/BotFP mog blizz
# 1                                                    Best way to aggro as a DK?
# 2                                           Blood DK dps in m+ during prepatch?
# 3                                             Might of the frozen waste changes
# 4                                        Coil of Devastation not working in PVP
# 5                                         Hardest mage tower skin to acquire DK
# 6                                    The “New” DPS Dk Feels Mindless and Boring
# 7                                                                Marrowrend Fix
# 8                                                Why is this two talent points?
# 9                                                             How to Summon Pet
# 10                                        Unholy Bond and Frost 2H PVP question
# 11                                                        Soul reaper is a joke
# 12                            [WotLK Classic] Dual-Wield Frost Tank Discussion!
# 13                                         Frost/Unholy DK looking good for DF?
# 14                                               Unholy dk class design for pvp
# 15                                                               DK arena comps
# 16                                  Are frost DKs still a support class in PvP?
# 17                                      Thoughts on Consumption talent for BDK?
# 18                                                    Frost empower rune weapon
# 19                                Cases where Dual Wield Blood might be viable?
# 20                                   Swap Cleaving Strikes and Unholy Endurance
# 21                                   DK is the only class with no new abilities
# 22                                 2H Frost DK is basically dead until level 70
# 23                          Is there a limit to Dark Arbiter’s damage increase?
# 24                         Unholy “Scaling Issues” (WotLKC)/Potential Solutions
# 25                                                             PvE Blood builds
# 26  Please for the love of Odin revert the Virulent Plague duration nerf in PvP
# 27                                                What does DRW do defensively?
# 28                                                     Blood DK Talent Tree Art
# 29                                      Death’s due as a glyph for Dragonflight
#
#           author views  replies
# 0        Grømmar   928      326
# 1      Devilmonk    10        0
# 2      Chantilus  1.2k       32
# 3     Gorezerker  2.6k       84
# 4   Emptythreats    20        0
# 5       Antisect   678       19
# 6   Nomensatanae  3.1k       45
# 7     Roninbones   412       12
# 8        Tanakar   240        1
# 9        Solusek   181        3
# 10    Dreadmoore   180        1
# 11         Jimmy  2.0k       26
# 12        Jaynai   323        1
# 13        Xristø   562       10
# 14         Bryku  1.3k       11
# 15       Virtúen   193        2
# 16       Runeboy   481        5
# 17  Trustlvlfour   274       10
# 18    Chillpills   610       21
# 19        Wilbur   229        3
# 20          Zeas    64        0
# 21       Malgarr  1.5k       35
# 22      Darthkon  4.2k      168
# 23          Dûsk   114        1
# 24      Killawar    82        0
# 25  Moonshinefox   152        1
# 26    Delichious   259        1
# 27       Joriand   304        2
# 28    Obviousman   225        2
# 29        Kevers   384        5
