# %%
import time

import pandas as pd
# import seaborn as sns
import selenium
# import webdriver_manager
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.firefox.options import Options
import undetected_chromedriver.v2 as uc
from random import randint

# %%
df = pd.read_csv(r'C:\Users\sarah\OneDrive\Documents\GitHub\psychic-invention\test_data.csv')

# %%
df 
# DT = parser.parse("Jun 23 2022 07:31PM")
# Out:
#     post_id  \
# 0    post_1
# 1    post_2
# 2    post_3
# 3    post_4
# 4    post_5
# 5    post_6
# 6    post_7
# 7    post_8
# 8    post_9
# 9   post_10
# 10  post_11
# 11  post_12
# 12  post_13
# 13  post_14
# 14  post_15
# 15  post_16
# 16  post_17
# 17  post_18
# 18  post_19
# 19  post_20
# 20  post_21
# 21  post_22
# 22  post_23
# 23  post_24
# 24  post_25
# 25  post_26
# 26  post_27
# 27  post_28
# 28  post_29
# 29  post_30
# 30  post_31
# 31  post_32
# 32  post_33
# 33  post_34
# 34  post_35
# 35  post_36
# 36  post_37
# 37  post_38
# 38  post_39
#
#                                                                                                                                                                                                                                                                                                                                                                          comment  \
# ...

# %%
def clean_data(df):
    likes = df['likes']
    for l in range(len(likes)):
        if likes[l].isdigit() == False:
            likes[l] ='0'
    df['likes'] = likes
    time = df["date"].values
    time = pd.to_datetime(time)
    time = time.tz_localize("US/Eastern")
    time = time.tz_convert('UTC')
    df['date'] = time


    return df

# %%
df = clean_data(df)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [233], line 1
# ----> 1 df = clean_data(df)
#       2 df
#
# Cell In [232], line 4, in clean_data(df)
#       2 likes = df['likes']
#       3 for l in range(len(likes)):
# ----> 4     if likes[l].isdigit() == False:
#       5         likes[l] ='0'
#       6 df['likes'] = likes
#
# AttributeError: 'numpy.int64' object has no attribute 'isdigit'

# %%
#post_49 > div > div.topic-body.clearfix > div.regular.contents.avoid-tab > div
# .timeline-replies

# %%
# div > div > div.timeline-scrollarea-wrapper.selectorgadget_selected > div.timeline-scrollarea > div.timeline-scroller > div.timeline-scroller-content > div.timeline-replies


# /html/body/section/div/div[4]/div[3]/div[3]/div[2]/div[2]/div/div/div[2]/div[2]/div[2]/div[2]/div[1]

#post_1 > div > div.topic-body.clearfix.highlighted > div.topic-map > section.map > ul > li.replies > span

#post_2 > div > div.topic-body.clearfix > div.regular.contents > div

# driver.execute_script("document.getElementById('your ID Element').scrollIntoView();")
# #post_1 > div > div.topic-body.clearfix.highlighted > div.regular.contents > section > nav > div > div > button.widget-button.btn.button-count.like-count.highlight-action.regular-likes.btn-text.selectorgadget_selected
# #post_3 > div > div.topic-body.clearfix > div.regular.contents > section > nav > div > div > button
